# %% [markdown]
# <a href="https://colab.research.google.com/github/sayedalikarthikappalli-alt/PROVIDENCE-COLLEGE-OF-ENGINEERING-/blob/main/2_validation_testing.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from sklearn.linear_model import Perceptron
import pandas as pd
from sklearn.model_selection import train_test_split
from  sklearn.metrics import accuracy_score
file = pd.read_csv("/content/irisexcel.csv")
x = file[["sepal_length","sepal_width","petal_length","petal_width"]]
y = file["species"]
#data splitting
x_train,x_test,y_train,y_test = train_test_split(x,y,test_size = 0.2)


model = Perceptron()
model.fit(x_train,y_train)
#validation test
prediction = model.predict(x_test)
#accuracy calculation
accuracy = accuracy_score(y_test,prediction)
print("accuracy is ",accuracy*100)
#final test
res = model.predict([[1.2,1.4,1.3,1.5]])
print(res)
# Out:
# accuracy is  90.0
# ['virginica']
# /usr/local/lib/python3.12/dist-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but Perceptron was fitted with feature names
#   warnings.warn(

# %%
from sklearn.metrics import confusion_matrix,ConfusionMatrixDisplay
import matplotlib.pyplot as plt
cm = confusion_matrix(y_test,prediction)
print(cm)
cmd = ConfusionMatrixDisplay(confusion_matrix =cm,display_labels = model.classes_)
cmd.plot()
# Out:
# [[10  0  0]
#  [ 0 12  3]
#  [ 0  0  5]]
