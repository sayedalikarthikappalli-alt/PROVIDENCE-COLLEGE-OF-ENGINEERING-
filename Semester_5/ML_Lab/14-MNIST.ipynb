# %% [markdown]
# <a href="https://colab.research.google.com/github/sayedalikarthikappalli-alt/PROVIDENCE-COLLEGE-OF-ENGINEERING-/blob/main/Semester_5/ML_Lab/14-MNIST.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from sklearn.neural_network import MLPClassifier
from sklearn.preprocessing import StandardScaler
import time
from tensorflow.keras.datasets import mnist
#importing the data....
(x_train,y_train),(x_test,y_test) = mnist.load_data()

x_train = x_train.reshape(len(x_train),784)
x_test = x_test.reshape(len(x_test),784)
x_train = x_train[1:10000]
x_test = x_test[1 : 2000]
y_train = y_train[1:10000]
y_test = y_test[1:2000]
i=0
#trainiig multiple models using for loop......
activations  = [
    "logistic",
    "relu",
    "tanh"
]
for activation in activations :
  i = i + 1
  mlp = MLPClassifier(hidden_layer_sizes = (100,),activation = activation)
  start = time.time()
  mlp.fit(x_train,y_train)
  training_time = time.time() - start
  y_pred = mlp.predict(x_test)
  accuracy = accuracy_score(y_test,y_pred)
  print(f"Model {i} \t")
  print(f"Accuracy :",accuracy * 100)
  print("\t Traning Time",round(training_time,2),"seconds \n")
# Out:
# Model 1
# Accuracy : 92.29614807403702
# 	 Traning Time 63.63 seconds
#
# Model 2
# Accuracy : 89.09454727363682
# 	 Traning Time 13.71 seconds
#
# Model 3
# Accuracy : 89.39469734867433
# 	 Traning Time 31.13 seconds
